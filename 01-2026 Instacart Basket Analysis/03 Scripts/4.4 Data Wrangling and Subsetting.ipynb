# %% [markdown]
# Exercise 4.3 wrangling proceedures

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing dataset departments.csv
df_dep = pd.read_csv(os.path.join(r"C:\Users\Emily\01-2026 Instacart Basket Analysis", '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# Transposing df_dep
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Creating a new dataframe from the transposed version
df_dep_t = df_dep.T

# %%
# Executing new dataframe
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Adding an Index
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Create a new header
new_header = df_dep_t.iloc[0]

# %%
# Seeing contents of first row
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# Remove the first row in the dataframe
df_dep_t_new = df_dep_t[1:]

# %%
# Executing new dataframe
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# Setting new header
df_dep_t_new.columns = new_header

# %%
#Seeing what the new header looks like in the dataframe
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Turning df_dep_t_new dataframe into a data dictionary
data_dict = df_dep_t_new.to_dict('index')

# %%
# Calling the new variable
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing dataset ptoducts.csv
df_prods = pd.read_csv(os.path.join(r"C:\Users\Emily\01-2026 Instacart Basket Analysis", '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
# Seeing first 5 emtries of df_prods
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Determining what deprtment-id 19 stands for
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
# Creating a subset for df_prods dataframe that only contains data from the snacks department
df_prods[ df_prods['department_id']==19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
# Saving results into new dataframe
df_snacks =  df_prods[df_prods['department_id']==19]

# %%
# Executing new df_snacks dataframe
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %% [markdown]
# Task 4.3 proceedures

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# create data path
path = r"C:\Users\Emily\01-2026 Instacart Basket Analysis"

# %%
# Import data csv's

# Order's data
df_ords = pd.read_csv(os.path.join(r"C:\Users\Emily\01-2026 Instacart Basket Analysis", '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# Product's data
df_prods = pd.read_csv(os.path.join(r"C:\Users\Emily\01-2026 Instacart Basket Analysis", '02 Data', 'Original Data', 'products.csv'), index_col = False)

# Department's data
df_dep = pd.read_csv(os.path.join(r"C:\Users\Emily\01-2026 Instacart Basket Analysis", '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %% [markdown]
# Step 2

# %%
# Displaying first 5 rows from orders dataframe
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# # Changing data type of order_number to non-numeric
df_ords['order_number'] = df_ords['order_number'].astype('str')

# %%
# Changing data type of order_id to non-numeric
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
# Changing data type of user_id to non-numeric
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
# Checking the data type
df_ords.dtypes
# Out:
# order_id                   object
# user_id                    object
# order_number               object
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %% [markdown]
# Step 3

# %%
# Changing order_dow to orders_day_of_week
df_ords.rename(columns={'order_dow': 'order_day_of_week'}, inplace=True)

# %%
# Checking that the name was changed correctly
df_ords.head()
# Out:
#   order_id user_id order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1            1                   2                  8
# 1  2398795       1            2                   3                  7
# 2   473747       1            3                   3                 12
# 3  2254736       1            4                   4                  7
# 4   431534       1            5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# Step 4

# %%
# Finding the frequency
df_ords['order_hour_of_day'].value_counts(dropna=True)
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# 10:00 is the busiest hour of the day for placing orders.

# %% [markdown]
# Step 5

# %%
# Retrieving data dictionary
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
# Meaning of 4 in data dictionary for df_prods
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# 4 means produce.

# %% [markdown]
# Step 6

# %%
# Creating a subset of breakfast items sales data
df_bfast = df_prods[df_prods['department_id']== 14]

# %%
# Retreiving the information
df_prods_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# Step 7

# %%
# Creating subset for dinner party for the departments alcohol, deli, beverages, and meat/seafood.
# Data dictionary shows that the numbers for these departments are 5, 20, 7 and 12.
df_prods_dinner_party = df_prods.loc[df_prods['department_id'].isin([5, 7, 12, 20])]

# %%
df_prods_dinner_party.head()
# Out:
#     product_id                                    product_name  aisle_id  \
# 2            3            Robust Golden Unsweetened Oolong Tea        94
# 6            7                  Pure Coconut Water With Orange        98
# 9           10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                               Peach Mango Juice        31
# 16          17                               Rendered Duck Fat        35
#
#     department_id  prices
# 2               7     4.5
# 6               7     4.4
# 9               7     8.4
# 10              7     2.8
# 16             12    17.1

# %% [markdown]
# Step 8

# %%
# How many rows does the last dataframe you created have?
df_prods_dinner_party.shape
# Out:
# (7650, 5)

# %% [markdown]
# The last data set has 7,650 rows.

# %% [markdown]
# Step 9

# %%
# Details about customer with user_id 1
df_user1 = df_ords.loc[df_ords['user_id'] == '1']

# %%
#Extracting info
df_user1
# Out:
#    order_id user_id order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1            1                   2                  8
# 1   2398795       1            2                   3                  7
# 2    473747       1            3                   3                 12
# 3   2254736       1            4                   4                  7
# 4    431534       1            5                   4                 15
# 5   3367565       1            6                   2                  7
# 6    550135       1            7                   1                  9
# 7   3108588       1            8                   1                 14
# 8   2295261       1            9                   1                 16
# 9   2550362       1           10                   4                  8
# 10  1187899       1           11                   4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %% [markdown]
# Step 10

# %%
# Info about user_id 1 behaviour
df_user1.describe()
# Out:
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count           11.000000          11.000000               10.000000
# mean             2.636364          10.090909               19.000000
# std              1.286291           3.477198                9.030811
# min              1.000000           7.000000                0.000000
# 25%              1.500000           7.500000               14.250000
# 50%              3.000000           8.000000               19.500000
# 75%              4.000000          13.000000               26.250000
# max              4.000000          16.000000               30.000000

# %% [markdown]
# This customer usually orders at the beginning of the week around 10:00am. On average, they place an order every 9 days. Also, they have never gone more than 30 days without ordering.

# %% [markdown]
# Step 12

# %%
# Export df_ords dataframe
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %% [markdown]
# Step 13

# %%
# Export df_dep_t_new dataframe
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))
