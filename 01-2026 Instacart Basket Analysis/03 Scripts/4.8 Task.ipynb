# %% [markdown]
# Step 1

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Creating Path
path = r"C:\Users\Emily\01-2026 Instacart Basket Analysis"

# %%
# Importing orders_products_merged_extra_columns.pkl File
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data' , 'Prepared Data' , 'orders_products_merged_extra_columns.pkl'))

# %%
# Checking the shape of the dataframe
df_ords_prods_merge.shape
# Out:
# (1000000, 19)

# %%
# Checking whether the import was successful
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0        1987   3139998      138            28                   6
# 1        1989   1977647      138            30                   6
# 2       11433    389851      709             2                   0
# 3       12198    652770      764             1                   3
# 4       12200   1813452      764             3                   4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# 0                 11                     3.0                  5          0
# 1                 17                    20.0                  1          1
# 2                 21                     6.0                 20          0
# 3                 13                     NaN                 10          0
# 4                 17                     9.0                 11          1
#
#   _merge    price_range_loc     busiest_day    busiest_days  \
# 0   both  Mid-range product  Regularly busy  Regularly busy
# 1   both  Mid-range product  Regularly busy  Regularly busy
# 2   both  Mid-range product     Busiest day    Busiest days
# 3   both  Mid-range product  Regularly busy    Slowest days
# 4   both  Mid-range product      Least busy    Slowest days
#
#   busiest_period_of_day
# 0           Most orders
# 1        Average orders
# 2        Average orders
# 3           Most orders
# 4        Average orders

# %%
# Creating a subset
df = df_ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %% [markdown]
# Step 2

# %%
#  Finding the aggregated mean for the entire dataframe
df_ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
df_ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %% [markdown]
# Step 3

# %% [markdown]
# The full dataframe generally has higher average order numbers across departments, showing it captures more customer behavior than the subset. Departmetn 21 hads the highest mean in both dataframes. Department 10 shows a mean that is 2 points higher in the full dataset. Most departments have similar order averages, but a few are slightly higher or lower in the full dataset.

# %% [markdown]
# Step 4

# %%
# Aggregating Data with transform() Function
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\Emily\AppData\Local\Temp\ipykernel_11620\3473307984.py:2: FutureWarning: The provided callable <function max at 0x000002202F9945E0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Checking the Output
df_ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# 11           1  Chocolate Sandwich Cookies        61             19     5.8
# 12           1  Chocolate Sandwich Cookies        61             19     5.8
# 13           1  Chocolate Sandwich Cookies        61             19     5.8
# 14           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0         1987   3139998      138            28                   6
# 1         1989   1977647      138            30                   6
# 2        11433    389851      709             2                   0
# 3        12198    652770      764             1                   3
# 4        12200   1813452      764             3                   4
# 5        12372   1701441      777            16                   1
# 6        13096   1871483      825             3                   2
# 7        14603   1290456      910            12                   3
# 8        17065    369558     1052            10                   1
# 9        17070    589712     1052            15                   1
# 10       22082   1798115     1379             1                   5
# 11       23713    497193     1480            36                   3
# 12       23715   1727826     1480            38                   4
# 13       23716   2694698     1480            39                   2
# 14       23937   3171753     1494             6                   3
#
#     order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# 0                  11                     3.0                  5          0
# 1                  17                    20.0                  1          1
# 2                  21                     6.0                 20          0
# 3                  13                     NaN                 10          0
# 4                  17                     9.0                 11          1
# 5                   7                    26.0                  7          0
# 6                  14                    30.0                  2          0
# 7                  10                    30.0                  1          0
# 8                  20                    19.0                  1          0
# 9                  12                    15.0                  2          1
# 10                 11                     NaN                  1          0
# 11                 13                     7.0                  1          0
# 12                 13                     7.0                  3          1
# 13                 12                    12.0                  4          1
# 14                 10                     2.0                  8          0
#
#    _merge    price_range_loc     busiest_day    busiest_days  \
# 0    both  Mid-range product  Regularly busy  Regularly busy
# 1    both  Mid-range product  Regularly busy  Regularly busy
# 2    both  Mid-range product     Busiest day    Busiest days
# 3    both  Mid-range product  Regularly busy    Slowest days
# 4    both  Mid-range product      Least busy    Slowest days
# 5    both  Mid-range product  Regularly busy    Busiest days
# 6    both  Mid-range product  Regularly busy  Regularly busy
# 7    both  Mid-range product  Regularly busy    Slowest days
# 8    both  Mid-range product  Regularly busy    Busiest days
# 9    both  Mid-range product  Regularly busy    Busiest days
# 10   both  Mid-range product  Regularly busy  Regularly busy
# 11   both  Mid-range product  Regularly busy    Slowest days
# 12   both  Mid-range product      Least busy    Slowest days
# 13   both  Mid-range product  Regularly busy  Regularly busy
# 14   both  Mid-range product  Regularly busy    Slowest days
#
#    busiest_period_of_day  max_order
# 0            Most orders         30
# 1         Average orders         30
# 2         Average orders          5
# 3            Most orders          3
# 4         Average orders          3
# 5         Average orders         16
# 6            Most orders          3
# 7            Most orders         12
# 8         Average orders         18
# 9            Most orders         18
# 10           Most orders          6
# 11           Most orders         41
# 12           Most orders         41
# 13           Most orders         41
# 14           Most orders          9

# %%
# Creating a 'Loyalty' Label Flag using loc Function
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    473070
# Loyal customer      287917
# New customer        239013
# Name: count, dtype: int64

# %%
# Checking the Updated Output
df_ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# 11           1  Chocolate Sandwich Cookies        61             19     5.8
# 12           1  Chocolate Sandwich Cookies        61             19     5.8
# 13           1  Chocolate Sandwich Cookies        61             19     5.8
# 14           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  ...  \
# 0         1987   3139998      138            28                   6  ...
# 1         1989   1977647      138            30                   6  ...
# 2        11433    389851      709             2                   0  ...
# 3        12198    652770      764             1                   3  ...
# 4        12200   1813452      764             3                   4  ...
# 5        12372   1701441      777            16                   1  ...
# 6        13096   1871483      825             3                   2  ...
# 7        14603   1290456      910            12                   3  ...
# 8        17065    369558     1052            10                   1  ...
# 9        17070    589712     1052            15                   1  ...
# 10       22082   1798115     1379             1                   5  ...
# 11       23713    497193     1480            36                   3  ...
# 12       23715   1727826     1480            38                   4  ...
# 13       23716   2694698     1480            39                   2  ...
# 14       23937   3171753     1494             6                   3  ...
#
#     days_since_prior_order  add_to_cart_order  reordered  _merge  \
# 0                      3.0                  5          0    both
# 1                     20.0                  1          1    both
# 2                      6.0                 20          0    both
# 3                      NaN                 10          0    both
# 4                      9.0                 11          1    both
# 5                     26.0                  7          0    both
# 6                     30.0                  2          0    both
# 7                     30.0                  1          0    both
# 8                     19.0                  1          0    both
# 9                     15.0                  2          1    both
# 10                     NaN                  1          0    both
# 11                     7.0                  1          0    both
# 12                     7.0                  3          1    both
# 13                    12.0                  4          1    both
# 14                     2.0                  8          0    both
#
#       price_range_loc     busiest_day    busiest_days busiest_period_of_day  \
# 0   Mid-range product  Regularly busy  Regularly busy           Most orders
# 1   Mid-range product  Regularly busy  Regularly busy        Average orders
# 2   Mid-range product     Busiest day    Busiest days        Average orders
# 3   Mid-range product  Regularly busy    Slowest days           Most orders
# 4   Mid-range product      Least busy    Slowest days        Average orders
# 5   Mid-range product  Regularly busy    Busiest days        Average orders
# 6   Mid-range product  Regularly busy  Regularly busy           Most orders
# 7   Mid-range product  Regularly busy    Slowest days           Most orders
# 8   Mid-range product  Regularly busy    Busiest days        Average orders
# 9   Mid-range product  Regularly busy    Busiest days           Most orders
# 10  Mid-range product  Regularly busy  Regularly busy           Most orders
# 11  Mid-range product  Regularly busy    Slowest days           Most orders
# 12  Mid-range product      Least busy    Slowest days           Most orders
# 13  Mid-range product  Regularly busy  Regularly busy           Most orders
# 14  Mid-range product  Regularly busy    Slowest days           Most orders
#
#    max_order      loyalty_flag
# 0         30  Regular customer
# 1         30  Regular customer
# 2          5      New customer
# 3          3      New customer
# 4          3      New customer
# 5         16  Regular customer
# 6          3      New customer
# 7         12  Regular customer
# 8         18  Regular customer
# 9         18  Regular customer
# 10         6      New customer
# 11        41    Loyal customer
# 12        41    Loyal customer
# 13        41    Loyal customer
# 14         9      New customer
#
# [15 rows x 21 columns]

# %% [markdown]
# Step 5

# %%
# Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category: (Loyal Customer, Regular Customer, and New Customer) 
df_ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.674593  1.0  24.5
# New customer      7.792591  1.0  24.5
# Regular customer  7.750368  1.0  24.5

# %% [markdown]
# The average product prices are similar for all three customer types.

# %% [markdown]
# Step 6

# %%
# Create a spending flag for each user based on the average price across all their orders using the following criteria:
# 1) If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# 2) If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# Aggregating Data with transform() Function
df_ords_prods_merge['avg_product_price'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\Emily\AppData\Local\Temp\ipykernel_11620\1144848887.py:2: FutureWarning: The provided callable <function mean at 0x000002202F994FE0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_ords_prods_merge['avg_product_price'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Checking Relevant Columns 
df_ords_prods_merge[['user_id', 'avg_product_price']].head(15)
# Out:
#     user_id  avg_product_price
# 0       138          12.900000
# 1       138          12.900000
# 2       709           5.288889
# 3       764           5.800000
# 4       764           5.800000
# 5       777           5.800000
# 6       825           5.800000
# 7       910           5.800000
# 8      1052           7.000000
# 9      1052           7.000000
# 10     1379           7.400000
# 11     1480           8.422222
# 12     1480           8.422222
# 13     1480           8.422222
# 14     1494           5.736364

# %%
# Creating a Spending Label Flag using loc Function
df_ords_prods_merge.loc[df_ords_prods_merge['avg_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['avg_product_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
df_ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     805506
# High spender    194494
# Name: count, dtype: int64

# %%
# Checking Releavent Columns
df_ords_prods_merge[['user_id', 'avg_product_price', 'spending_flag']].head(15)
# Out:
#     user_id  avg_product_price spending_flag
# 0       138          12.900000  High spender
# 1       138          12.900000  High spender
# 2       709           5.288889   Low spender
# 3       764           5.800000   Low spender
# 4       764           5.800000   Low spender
# 5       777           5.800000   Low spender
# 6       825           5.800000   Low spender
# 7       910           5.800000   Low spender
# 8      1052           7.000000   Low spender
# 9      1052           7.000000   Low spender
# 10     1379           7.400000   Low spender
# 11     1480           8.422222   Low spender
# 12     1480           8.422222   Low spender
# 13     1480           8.422222   Low spender
# 14     1494           5.736364   Low spender

# %% [markdown]
# Step 7

# %%
# Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column.
df_ords_prods_merge['median_days_between_orders'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\Emily\AppData\Local\Temp\ipykernel_11620\1694169079.py:2: FutureWarning: The provided callable <function median at 0x000002202FB740E0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df_ords_prods_merge['median_days_between_orders'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Checking Relevant Columns 
df_ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders']].head(15)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders
# 0       138                     3.0                         6.5
# 1       138                    20.0                         6.5
# 2       709                     6.0                         7.0
# 3       764                     NaN                         9.0
# 4       764                     9.0                         9.0
# 5       777                    26.0                        26.0
# 6       825                    30.0                        30.0
# 7       910                    30.0                        30.0
# 8      1052                    19.0                        12.0
# 9      1052                    15.0                        12.0
# 10     1379                     NaN                        13.0
# 11     1480                     7.0                         7.0
# 12     1480                     7.0                         7.0
# 13     1480                    12.0                         7.0
# 14     1494                     2.0                         6.0

# %%
# Creating a 'Order Frequency' Label Flag using loc Function
df_ords_prods_merge.loc[df_ords_prods_merge['median_days_between_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['median_days_between_orders'] <= 20) & (df_ords_prods_merge['median_days_between_orders'] > 10), 'order_frequency_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['median_days_between_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
df_ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        641346
# Regular customer         221585
# Non-frequent customer    128877
# NaN                        8192
# Name: count, dtype: int64

# %%
# Checking Relevant Columns of Updated Dataframe
df_ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders', 'order_frequency_flag']].head(15)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders  \
# 0       138                     3.0                         6.5
# 1       138                    20.0                         6.5
# 2       709                     6.0                         7.0
# 3       764                     NaN                         9.0
# 4       764                     9.0                         9.0
# 5       777                    26.0                        26.0
# 6       825                    30.0                        30.0
# 7       910                    30.0                        30.0
# 8      1052                    19.0                        12.0
# 9      1052                    15.0                        12.0
# 10     1379                     NaN                        13.0
# 11     1480                     7.0                         7.0
# 12     1480                     7.0                         7.0
# 13     1480                    12.0                         7.0
# 14     1494                     2.0                         6.0
#
#      order_frequency_flag
# 0       Frequent customer
# 1       Frequent customer
# 2       Frequent customer
# 3       Frequent customer
# 4       Frequent customer
# 5   Non-frequent customer
# 6   Non-frequent customer
# 7   Non-frequent customer
# 8        Regular customer
# 9        Regular customer
# 10       Regular customer
# 11      Frequent customer
# 12      Frequent customer
# 13      Frequent customer
# 14      Frequent customer

# %% [markdown]
# Step 9

# %%
# Exporting the dataframe as a pickle file 
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_grouped.pkl'))
